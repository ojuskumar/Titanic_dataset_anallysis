# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic=pd.read_csv(r"C:\Users\91909\titanic_dataset\train.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
##Age,Cabin,Embarked have null values

# %%
titanic.describe()['Age']
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
##Univariate analysis for categorical Variables

# %%
survived = titanic['Survived']
pclass = titanic['Pclass']
gender = titanic['Sex']
station = titanic['Embarked']

l = [survived ,pclass , gender ,station]

for i in range(len(l)):
    print(l[i].value_counts()) # counting the values 
    sns.countplot(x = l[i]) #ploting them by iterating over list
    plt.show()
    plt.clf() # #The clf() function of pyplot module is used to clear the current figure.
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# male      577
# female    314
# Name: Sex, dtype: int64
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#pie chart

# %%
for i in range(len(l)):
    l[i].value_counts().plot(kind='pie',autopct=',%2f')
    plt.show()
    plt.clf

# %%
##Numerical Data

# %%
sns.histplot(x=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.displot(x=titanic['Age'],kde=True)
plt.show()
plt.clf()
sns.kdeplot(x=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(x=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
##Multivariate Analysis

# %%
p_class=titanic['Pclass']
age=titanic['Age']
fare=titanic['Fare']
gender=titanic['Sex']
sns.barplot(x=p_class,y=fare,hue=gender)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x=gender,y=age,hue=survived)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
not_survived_age=titanic['Survived']==1
survived_age=titanic['Survived']==0
sns.kdeplot(titanic[not_survived_age]['Age'])
sns.kdeplot(titanic[survived_age]['Age'])
plt.show()
plt.clf()

# %%
crosstab_data=pd.crosstab(titanic['Pclass'],titanic['Survived'])
print(crosstab_data)
sns.heatmap(crosstab_data)
# Out:
# Survived    1
# Pclass
# 1         216
# 2         184
# 3         491
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
parch_survival=pd.crosstab(titanic['Parch'],titanic['Survived'])
print(parch_survival)
sns.clustermap(parch_survival)
# Out:
# Survived    1
# Parch
# 0         678
# 1         118
# 2          80
# 3           5
# 4           4
# 5           5
# 6           1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8ec05b7e95d6> in <module>
#       1 parch_survival=pd.crosstab(titanic['Parch'],titanic['Survived'])
#       2 print(parch_survival)
# ----> 3 sns.clustermap(parch_survival)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1400                           colors_ratio=colors_ratio, cbar_pos=cbar_pos)
#    1401
# -> 1402     return plotter.plot(metric=metric, method=method,
#    1403                         colorbar_kws=cbar_kws,
#    1404                         row_cluster=row_cluster, col_cluster=col_cluster,
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1218         colorbar_kws = {} if colorbar_kws is None else colorbar_kws
#    1219
# -> 1220         self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1221                               row_linkage=row_linkage, col_linkage=col_linkage,
#    1222                               tree_kws=tree_kws)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#    1073         # PLot the column dendrogram
#    1074         if col_cluster:
# -> 1075             self.dendrogram_col = dendrogram(
#    1076                 self.data2d, metric=metric, method=method, label=False,
#    1077                 axis=1, ax=self.ax_col_dendrogram, linkage=col_linkage,
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     782
#     783     """
# --> 784     plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     785                                  metric=metric, method=method,
#     786                                  label=label, rotate=rotate)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, linkage, metric, method, axis, label, rotate)
#     592
#     593         if linkage is None:
# --> 594             self.linkage = self.calculated_linkage
#     595         else:
#     596             self.linkage = linkage
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in calculated_linkage(self)
#     659                 warnings.warn(msg)
#     660
# --> 661         return self._calculate_linkage_scipy()
#     662
#     663     def calculate_dendrogram(self):
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in _calculate_linkage_scipy(self)
#     627
#     628     def _calculate_linkage_scipy(self):
# --> 629         linkage = hierarchy.linkage(self.array, method=self.method,
#     630                                     metric=self.metric)
#     631         return linkage
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1066                          "finite values.")
#    1067
# -> 1068     n = int(distance.num_obs_y(y))
#    1069     method_code = _LINKAGE_METHODS[method]
#    1070
#
# ~\Anaconda3\lib\site-packages\scipy\spatial\distance.py in num_obs_y(Y)
#    2571     k = Y.shape[0]
#    2572     if k == 0:
# -> 2573         raise ValueError("The number of observations cannot be determined on "
#    2574                          "an empty distance matrix.")
#    2575     d = int(np.ceil(np.sqrt(k * 2)))
#
# ValueError: The number of observations cannot be determined on an empty distance matrix.

# %%
titanic.groupby('Embarked').mean()['Survived']*100
# Out:
# Embarked
# C    100.0
# Q    100.0
# S    100.0
# Name: Survived, dtype: float64

# %%
train_data = pd.read_csv(r"C:\Users\91909\titanic_dataset\train.csv")
test_data = pd.read_csv(r"C:\Users\91909\titanic_dataset\test.csv")

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(train_data[features])
X_test = pd.get_dummies(test_data[features])

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
